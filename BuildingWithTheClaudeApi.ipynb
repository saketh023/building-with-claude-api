# %%
# %pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
# Make a request
message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {"role": "user", "content": "Define quantum computing in one sentence"}
    ],
)

# %%
message.content[0].text
# Out:
# '**Quantum computing** is a type of computation that harnesses quantum mechanical phenomena — such as superposition and entanglement — to process information in ways that can solve certain complex problems exponentially faster than classical computers.'

# %%
def add_user_message(messages, text):
    user_message = {'role': 'user', 'content': text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {'role': 'assistant', 'content': text}
    messages.append(assistant_message)

def chat(messages):
    response = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return response.content[0].text

# %%
# Make a starting list of messages
messages=[]
# Add initial user question
add_user_message(messages, "Define quantum computing in one sentence")
# Pass the list of messages to 'chat' to get an answer
answer = chat(messages)
# Take the answer and add it as an assistant message to our list
add_assistant_message(messages, answer)
# Add in the user's follow-up question
add_user_message(messages, "Write another sentence.")
# # Call chat again with the list of messages to get a final answer
answer = chat(messages)

answer
# Out:
# 'Unlike classical computers, which store information as binary bits (0s or 1s), quantum computers use **qubits** that can exist in multiple states simultaneously, enabling them to perform vast numbers of calculations at the same time.'

# %%
messages
# Out:
# [{'role': 'user', 'content': 'Define quantum computing in one sentence'},
#  {'role': 'assistant',
#   'content': '**Quantum computing** is a type of computation that harnesses quantum mechanical phenomena—such as superposition and entanglement—to process information in ways that can solve certain complex problems exponentially faster than classical computers.'},
#  {'role': 'user', 'content': 'Write another sentence.'}]

# %%
messages = []

while True:
    user_input = input("> ")
    print(">", user_input)
    userMsg = {'role':'user', 'content':user_input}
    messages.append(userMsg)
    asstResponse = client.messages.create(model = model, max_tokens=1000, messages = messages)
    print(asstResponse.content[0].text)
    asstMsg = { 'role': 'assistant', 'content': asstResponse.content[0].text}
    messages.append(asstMsg)
    print(asstMsg)
# Out:
# > Hello, what is 2+5
# Hello! 2 + 5 = **7** 😊
#
# Is there anything else I can help you with?
# {'role': 'assistant', 'content': 'Hello! 2 + 5 = **7** 😊\n\nIs there anything else I can help you with?'}
# > yes add3 to the previous sum
# The previous sum was **7**, and adding 3 to it gives:
#
# 7 + 3 = **10** 😊
#
# Is there anything else I can help you with?
# {'role': 'assistant', 'content': 'The previous sum was **7**, and adding 3 to it gives:\n\n7 + 3 = **10** 😊\n\nIs there anything else I can help you with?'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 messages = []
#       3 while True:
# ----> 4     user_input = input("> ")
#       5     print(">", user_input)
#       6     userMsg = {'role':'user', 'content':user_input}
#
# File c:\Users\vsake\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1262, in Kernel.raw_input(self, prompt)
# ...
